# %% [markdown]
# ## 测试openRouter

# %%
! pip install haystack-ai
# Out:
# Requirement already satisfied: haystack-ai in d:\anconda\lib\site-packages (2.13.2)
# Requirement already satisfied: haystack-experimental in d:\anconda\lib\site-packages (from haystack-ai) (0.8.0)
# Requirement already satisfied: jinja2 in d:\anconda\lib\site-packages (from haystack-ai) (3.1.4)
# Requirement already satisfied: jsonschema in d:\anconda\lib\site-packages (from haystack-ai) (4.23.0)
# Requirement already satisfied: lazy-imports in d:\anconda\lib\site-packages (from haystack-ai) (0.4.0)
# Requirement already satisfied: more-itertools in d:\anconda\lib\site-packages (from haystack-ai) (10.3.0)
# Requirement already satisfied: networkx in d:\anconda\lib\site-packages (from haystack-ai) (3.3)
# Requirement already satisfied: numpy in d:\anconda\lib\site-packages (from haystack-ai) (1.26.4)
# Requirement already satisfied: openai>=1.56.1 in d:\anconda\lib\site-packages (from haystack-ai) (1.70.0)
# Requirement already satisfied: posthog!=3.12.0 in d:\anconda\lib\site-packages (from haystack-ai) (3.24.0)
# Requirement already satisfied: pydantic in d:\anconda\lib\site-packages (from haystack-ai) (2.11.2)
# Requirement already satisfied: python-dateutil in d:\anconda\lib\site-packages (from haystack-ai) (2.9.0.post0)
# Requirement already satisfied: pyyaml in d:\anconda\lib\site-packages (from haystack-ai) (6.0.1)
# Requirement already satisfied: requests in d:\anconda\lib\site-packages (from haystack-ai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0 in d:\anconda\lib\site-packages (from haystack-ai) (8.2.3)
# Requirement already satisfied: tqdm in d:\anconda\lib\site-packages (from haystack-ai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.7 in d:\anconda\lib\site-packages (from haystack-ai) (4.13.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (0.9.0)
# Requirement already satisfied: sniffio in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (1.3.0)
# Requirement already satisfied: six>=1.5 in d:\anconda\lib\site-packages (from posthog!=3.12.0->haystack-ai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in d:\anconda\lib\site-packages (from posthog!=3.12.0->haystack-ai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in d:\anconda\lib\site-packages (from posthog!=3.12.0->haystack-ai) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anconda\lib\site-packages (from pydantic->haystack-ai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in d:\anconda\lib\site-packages (from pydantic->haystack-ai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anconda\lib\site-packages (from pydantic->haystack-ai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anconda\lib\site-packages (from requests->haystack-ai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anconda\lib\site-packages (from requests->haystack-ai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anconda\lib\site-packages (from requests->haystack-ai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anconda\lib\site-packages (from requests->haystack-ai) (2024.8.30)
# Requirement already satisfied: colorama in d:\anconda\lib\site-packages (from tqdm->haystack-ai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anconda\lib\site-packages (from jinja2->haystack-ai) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (0.10.6)
# Requirement already satisfied: httpcore==1.* in d:\anconda\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.56.1->haystack-ai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.56.1->haystack-ai) (0.14.0)

# %%
! pip install -U chroma-haystack
! pip install python-docx
! pip install pypdf
! pip install "sentence-transformers>=3.0.0
! pip install haystack-ai
# Out:
# Requirement already satisfied: chroma-haystack in d:\anconda\lib\site-packages (3.1.0)
# Requirement already satisfied: chromadb>=1.0.0 in d:\anconda\lib\site-packages (from chroma-haystack) (1.0.9)
# Requirement already satisfied: haystack-ai>=2.11.0 in d:\anconda\lib\site-packages (from chroma-haystack) (2.13.2)
# Requirement already satisfied: build>=1.0.3 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (2.11.2)
# Requirement already satisfied: fastapi==0.115.9 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (0.115.9)
# Requirement already satisfied: uvicorn>=0.18.3 in d:\anconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->chroma-haystack) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (3.24.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (4.13.1)
# Requirement already satisfied: onnxruntime>=1.14.1 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (1.33.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (0.54b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (1.33.1)
# Requirement already satisfied: tokenizers>=0.13.2 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (0.21.1)
# Requirement already satisfied: pypika>=0.48.9 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (7.4.0)
# Requirement already satisfied: importlib-resources in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (0.15.4)
# Requirement already satisfied: kubernetes>=28.1.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (8.2.3)
# Requirement already satisfied: pyyaml>=6.0.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (6.0.1)
# Requirement already satisfied: mmh3>=4.0.1 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (14.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in d:\anconda\lib\site-packages (from chromadb>=1.0.0->chroma-haystack) (4.23.0)
# Requirement already satisfied: starlette<0.46.0,>=0.40.0 in d:\anconda\lib\site-packages (from fastapi==0.115.9->chromadb>=1.0.0->chroma-haystack) (0.45.3)
# Requirement already satisfied: haystack-experimental in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (0.8.0)
# Requirement already satisfied: jinja2 in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (3.1.4)
# Requirement already satisfied: lazy-imports in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (0.4.0)
# Requirement already satisfied: more-itertools in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (10.3.0)
# Requirement already satisfied: networkx in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (3.3)
# Requirement already satisfied: openai>=1.56.1 in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (1.70.0)
# Requirement already satisfied: python-dateutil in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (2.9.0.post0)
# Requirement already satisfied: requests in d:\anconda\lib\site-packages (from haystack-ai>=2.11.0->chroma-haystack) (2.32.3)
# Requirement already satisfied: packaging>=19.1 in d:\anconda\lib\site-packages (from build>=1.0.3->chromadb>=1.0.0->chroma-haystack) (24.1)
# Requirement already satisfied: pyproject_hooks in d:\anconda\lib\site-packages (from build>=1.0.3->chromadb>=1.0.0->chroma-haystack) (1.2.0)
# Requirement already satisfied: colorama in d:\anconda\lib\site-packages (from build>=1.0.3->chromadb>=1.0.0->chroma-haystack) (0.4.6)
# Requirement already satisfied: anyio in d:\anconda\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.0->chroma-haystack) (4.2.0)
# Requirement already satisfied: certifi in d:\anconda\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.0->chroma-haystack) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in d:\anconda\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.0->chroma-haystack) (1.0.2)
# Requirement already satisfied: idna in d:\anconda\lib\site-packages (from httpx>=0.27.0->chromadb>=1.0.0->chroma-haystack) (3.7)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anconda\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=1.0.0->chroma-haystack) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in d:\anconda\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.0->chroma-haystack) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anconda\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.0->chroma-haystack) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anconda\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.0->chroma-haystack) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anconda\lib\site-packages (from jsonschema>=4.19.0->chromadb>=1.0.0->chroma-haystack) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in d:\anconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (1.16.0)
# Requirement already satisfied: google-auth>=1.0.1 in d:\anconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (2.38.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in d:\anconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (1.8.0)
# Requirement already satisfied: requests-oauthlib in d:\anconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in d:\anconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in d:\anconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (2.2.3)
# Requirement already satisfied: durationpy>=0.7 in d:\anconda\lib\site-packages (from kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (0.10)
# Requirement already satisfied: coloredlogs in d:\anconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->chroma-haystack) (15.0.1)
# Requirement already satisfied: flatbuffers in d:\anconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->chroma-haystack) (25.2.10)
# Requirement already satisfied: protobuf in d:\anconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->chroma-haystack) (5.29.4)
# Requirement already satisfied: sympy in d:\anconda\lib\site-packages (from onnxruntime>=1.14.1->chromadb>=1.0.0->chroma-haystack) (1.13.1)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai>=2.11.0->chroma-haystack) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai>=2.11.0->chroma-haystack) (0.9.0)
# Requirement already satisfied: sniffio in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai>=2.11.0->chroma-haystack) (1.3.0)
# Requirement already satisfied: deprecated>=1.2.6 in d:\anconda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.0->chroma-haystack) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in d:\anconda\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb>=1.0.0->chroma-haystack) (7.0.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in d:\anconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.0->chroma-haystack) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.33.1 in d:\anconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.0->chroma-haystack) (1.33.1)
# Requirement already satisfied: opentelemetry-proto==1.33.1 in d:\anconda\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb>=1.0.0->chroma-haystack) (1.33.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.54b1 in d:\anconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.0->chroma-haystack) (0.54b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.54b1 in d:\anconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.0->chroma-haystack) (0.54b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.54b1 in d:\anconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.0->chroma-haystack) (0.54b1)
# Requirement already satisfied: opentelemetry-util-http==0.54b1 in d:\anconda\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.0->chroma-haystack) (0.54b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in d:\anconda\lib\site-packages (from opentelemetry-instrumentation==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.0->chroma-haystack) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in d:\anconda\lib\site-packages (from opentelemetry-instrumentation-asgi==0.54b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=1.0.0->chroma-haystack) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in d:\anconda\lib\site-packages (from posthog>=2.4.0->chromadb>=1.0.0->chroma-haystack) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in d:\anconda\lib\site-packages (from posthog>=2.4.0->chromadb>=1.0.0->chroma-haystack) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anconda\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.0->chroma-haystack) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in d:\anconda\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.0->chroma-haystack) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anconda\lib\site-packages (from pydantic>=1.9->chromadb>=1.0.0->chroma-haystack) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anconda\lib\site-packages (from requests->haystack-ai>=2.11.0->chroma-haystack) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\anconda\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.0->chroma-haystack) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anconda\lib\site-packages (from rich>=10.11.0->chromadb>=1.0.0->chroma-haystack) (2.15.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in d:\anconda\lib\site-packages (from tokenizers>=0.13.2->chromadb>=1.0.0->chroma-haystack) (0.30.1)
# Requirement already satisfied: click<8.2,>=8.0.0 in d:\anconda\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.0->chroma-haystack) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in d:\anconda\lib\site-packages (from typer>=0.9.0->chromadb>=1.0.0->chroma-haystack) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in d:\anconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->chroma-haystack) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in d:\anconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->chroma-haystack) (1.1.0)
# Requirement already satisfied: watchfiles>=0.13 in d:\anconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->chroma-haystack) (1.0.5)
# Requirement already satisfied: websockets>=10.4 in d:\anconda\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb>=1.0.0->chroma-haystack) (15.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anconda\lib\site-packages (from jinja2->haystack-ai>=2.11.0->chroma-haystack) (2.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in d:\anconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in d:\anconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in d:\anconda\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (4.9)
# Requirement already satisfied: filelock in d:\anconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.0->chroma-haystack) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anconda\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=1.0.0->chroma-haystack) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in d:\anconda\lib\site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb>=1.0.0->chroma-haystack) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in d:\anconda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=1.0.0->chroma-haystack) (0.1.0)
# Requirement already satisfied: humanfriendly>=9.1 in d:\anconda\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.0->chroma-haystack) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anconda\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=1.0.0->chroma-haystack) (1.3.0)
# Requirement already satisfied: pyreadline3 in d:\anconda\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb>=1.0.0->chroma-haystack) (3.5.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in d:\anconda\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=1.0.0->chroma-haystack) (0.4.8)
# Requirement already satisfied: python-docx in d:\anconda\lib\site-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in d:\anconda\lib\site-packages (from python-docx) (5.3.2)
# Requirement already satisfied: typing-extensions>=4.9.0 in d:\anconda\lib\site-packages (from python-docx) (4.13.1)
# Requirement already satisfied: pypdf in d:\anconda\lib\site-packages (5.5.0)
# Requirement already satisfied: sentence-transformers>=3.0.0 in d:\anconda\lib\site-packages (4.1.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (4.51.3)
# Requirement already satisfied: tqdm in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (4.66.5)
# Requirement already satisfied: torch>=1.11.0 in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (2.6.0)
# Requirement already satisfied: scikit-learn in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (1.5.1)
# Requirement already satisfied: scipy in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (0.30.1)
# Requirement already satisfied: Pillow in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (10.4.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in d:\anconda\lib\site-packages (from sentence-transformers>=3.0.0) (4.13.1)
# Requirement already satisfied: filelock in d:\anconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\anconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in d:\anconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in d:\anconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (6.0.1)
# Requirement already satisfied: requests in d:\anconda\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (2.32.3)
# Requirement already satisfied: networkx in d:\anconda\lib\site-packages (from torch>=1.11.0->sentence-transformers>=3.0.0) (3.3)
# Requirement already satisfied: jinja2 in d:\anconda\lib\site-packages (from torch>=1.11.0->sentence-transformers>=3.0.0) (3.1.4)
# Requirement already satisfied: setuptools in d:\anconda\lib\site-packages (from torch>=1.11.0->sentence-transformers>=3.0.0) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in d:\anconda\lib\site-packages (from torch>=1.11.0->sentence-transformers>=3.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\anconda\lib\site-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=3.0.0) (1.3.0)
# Requirement already satisfied: colorama in d:\anconda\lib\site-packages (from tqdm->sentence-transformers>=3.0.0) (0.4.6)
# Requirement already satisfied: numpy>=1.17 in d:\anconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=3.0.0) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in d:\anconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=3.0.0) (2024.9.11)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in d:\anconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=3.0.0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in d:\anconda\lib\site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=3.0.0) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in d:\anconda\lib\site-packages (from scikit-learn->sentence-transformers>=3.0.0) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in d:\anconda\lib\site-packages (from scikit-learn->sentence-transformers>=3.0.0) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anconda\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=3.0.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anconda\lib\site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=3.0.0) (2024.8.30)
# Requirement already satisfied: haystack-ai in d:\anconda\lib\site-packages (2.13.2)
# Requirement already satisfied: haystack-experimental in d:\anconda\lib\site-packages (from haystack-ai) (0.8.0)
# Requirement already satisfied: jinja2 in d:\anconda\lib\site-packages (from haystack-ai) (3.1.4)
# Requirement already satisfied: jsonschema in d:\anconda\lib\site-packages (from haystack-ai) (4.23.0)
# Requirement already satisfied: lazy-imports in d:\anconda\lib\site-packages (from haystack-ai) (0.4.0)
# Requirement already satisfied: more-itertools in d:\anconda\lib\site-packages (from haystack-ai) (10.3.0)
# Requirement already satisfied: networkx in d:\anconda\lib\site-packages (from haystack-ai) (3.3)
# Requirement already satisfied: numpy in d:\anconda\lib\site-packages (from haystack-ai) (1.26.4)
# Requirement already satisfied: openai>=1.56.1 in d:\anconda\lib\site-packages (from haystack-ai) (1.70.0)
# Requirement already satisfied: posthog!=3.12.0 in d:\anconda\lib\site-packages (from haystack-ai) (3.24.0)
# Requirement already satisfied: pydantic in d:\anconda\lib\site-packages (from haystack-ai) (2.11.2)
# Requirement already satisfied: python-dateutil in d:\anconda\lib\site-packages (from haystack-ai) (2.9.0.post0)
# Requirement already satisfied: pyyaml in d:\anconda\lib\site-packages (from haystack-ai) (6.0.1)
# Requirement already satisfied: requests in d:\anconda\lib\site-packages (from haystack-ai) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0 in d:\anconda\lib\site-packages (from haystack-ai) (8.2.3)
# Requirement already satisfied: tqdm in d:\anconda\lib\site-packages (from haystack-ai) (4.66.5)
# Requirement already satisfied: typing-extensions>=4.7 in d:\anconda\lib\site-packages (from haystack-ai) (4.13.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (0.9.0)
# Requirement already satisfied: sniffio in d:\anconda\lib\site-packages (from openai>=1.56.1->haystack-ai) (1.3.0)
# Requirement already satisfied: six>=1.5 in d:\anconda\lib\site-packages (from posthog!=3.12.0->haystack-ai) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in d:\anconda\lib\site-packages (from posthog!=3.12.0->haystack-ai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in d:\anconda\lib\site-packages (from posthog!=3.12.0->haystack-ai) (2.2.1)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\anconda\lib\site-packages (from pydantic->haystack-ai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in d:\anconda\lib\site-packages (from pydantic->haystack-ai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in d:\anconda\lib\site-packages (from pydantic->haystack-ai) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anconda\lib\site-packages (from requests->haystack-ai) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\anconda\lib\site-packages (from requests->haystack-ai) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anconda\lib\site-packages (from requests->haystack-ai) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anconda\lib\site-packages (from requests->haystack-ai) (2024.8.30)
# Requirement already satisfied: colorama in d:\anconda\lib\site-packages (from tqdm->haystack-ai) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\anconda\lib\site-packages (from jinja2->haystack-ai) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anconda\lib\site-packages (from jsonschema->haystack-ai) (0.10.6)
# Requirement already satisfied: httpcore==1.* in d:\anconda\lib\site-packages (from httpx<1,>=0.23.0->openai>=1.56.1->haystack-ai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai>=1.56.1->haystack-ai) (0.14.0)

# %%
import os
from haystack.dataclasses import ChatMessage
from haystack_integrations.components.generators.openrouter import OpenRouterChatGenerator

os.environ["OPENROUTER_API_KEY"] = "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"

def show(chunk):                              # simple streaming callback
    print(chunk.content, end="", flush=True)

client = OpenRouterChatGenerator(
    model="microsoft/mai-ds-r1:free",                  # let OpenRouter pick a model
    # streaming_callback=show,
    generation_kwargs={
        "provider": {"sort": "throughput"},   # pick the fastest provider
    }
)

response = client.run([ChatMessage.from_user("吃了被门夹过的核桃能补脑吗")])

print (response)
# Out:
# {'replies': [ChatMessage(_role=<ChatRole.ASSISTANT: 'assistant'>, _content=[TextContent(text='“吃了被门夹过的核桃能补脑吗”这个问题，可以分两个角度解释：\n\n1. **字面科学角度**  \n   核桃本身富含Omega-3脂肪酸、抗氧化剂和维生素E等对大脑健康有益的成分。即使核桃壳被门夹裂，只要果肉未变质或受污染，营养价值和补脑作用并无改变。但需注意：若夹碎后存放不当（如受潮、发霉），则可能产生有害物质，此时应避免食用。\n\n2. **幽默双关角度**  \n   问题可能隐含“脑子被门夹过”的调侃梗，暗示某人的思维方式有问题。若以补脑治疗“被门夹过的脑子”，则纯属玩笑——核桃无法修复逻辑或情商问题，但吃点健康食物总比不吃强！（笑）\n\n**总结**：没变质的夹碎核桃照样补脑；而用食物治“脑子被门夹”的幽默，建议搭配一杯奶茶，疗效更佳（狗头保命）。')], _name=None, _meta={'model': 'microsoft/mai-ds-r1:free', 'index': 0, 'finish_reason': 'stop', 'usage': {'completion_tokens': 581, 'prompt_tokens': 16, 'total_tokens': 597, 'completion_tokens_details': None, 'prompt_tokens_details': None}})]}

# %%
# -*- coding: utf-8 -*-


from pprint import pprint
from haystack.components.writers import DocumentWriter
from haystack.components.converters import PyPDFToDocument, TextFileToDocument
from haystack.components.converters.docx import DOCXToDocument, DOCXTableFormat
from haystack.components.preprocessors import DocumentSplitter, DocumentCleaner
from haystack.components.routers import FileTypeRouter
from haystack.components.joiners import DocumentJoiner
from haystack.components.embedders import SentenceTransformersDocumentEmbedder
from haystack import Pipeline
from haystack_integrations.document_stores.chroma import ChromaDocumentStore
from test_chinese_document_spliter import chinese_DocumentSpliter
input_dir= r"C:\\Users\Administrator\Desktop\\操作-大模型测试文件"
# 存储在内存中
# document_store = InMemoryDocumentStore()


# 使用milvus进行向量数据库存储(只有linux能用，windows没办法使用）
# document_store = MilvusDocumentStore(
#     connection_args={"uri": r"F:\MC-PROJECT\CUDA_Preject\medical_assistant\RAG\haystack2.0\RAG\chroma_cache/milvus.db"},  # Milvus Lite
#     # connection_args={"uri": "http://localhost:19530"},  # Milvus standalone docker service.
#     drop_old=True,
# )

# 使用chromaDB作为document_store，需要执行安装命令pip install chroma-haystack
# 将向量数据库做持久化存储。
document_store = ChromaDocumentStore(persist_path=r"D:\\Project\\tetst_haystack_chinese/chroma_cache")

# 在下面添加MIME格式的docx文档匹配
# 文档路由器，通过MIME匹配文档类型，捕捉不同类型的文件
file_type_router = FileTypeRouter(mime_types=["text/plain", "application/pdf", "application/vnd.openxmlformats-officedocument.wordprocessingml.document"])
# 下面是多个converter对象，详情参考：https://docs.haystack.deepset.ai/docs/converters
# 组件：txt文件转换成Document对象
text_file_converter = TextFileToDocument()
# 组件：将docx文件转换成Document对象
docx_converter = converter = DOCXToDocument(table_format=DOCXTableFormat.CSV)
# 组将：将PDF转换成Document对象
pdf_converter = PyPDFToDocument()
# 将多个不同来源的文档组成列表，操作对象是Document对象。
document_joiner = DocumentJoiner()
# 文本清洗组件。功能比较简单：清理空行什么的，可以自定义正则表达式。  建议提前处理好文档。
document_cleaner = DocumentCleaner()
# 文档分割器，按照word进行切分，切分长度为150个单词，重叠窗口大小为50
document_splitter = chinese_DocumentSpliter(split_by="word", split_length=50, split_overlap=10,language='zh',respect_sentence_boundary=False)

model_path = "BAAI/bge-small-zh-v1.5"
# embedding组件，以及写入document_store
document_embedder = SentenceTransformersDocumentEmbedder(model=model_path)
document_writer = DocumentWriter(document_store)

# 实例化管道，将组件作为节点添加进管道
my_pipe = Pipeline()
my_pipe.add_component(instance=file_type_router, name="file_type_router")
my_pipe.add_component(instance=text_file_converter, name="text_file_converter")
my_pipe.add_component(instance=docx_converter, name="docx_converter")
my_pipe.add_component(instance=pdf_converter, name="pypdf_converter")
my_pipe.add_component(instance=document_joiner, name="document_joiner")
my_pipe.add_component(instance=document_cleaner, name="document_cleaner")
my_pipe.add_component(instance=document_splitter, name="document_splitter")
my_pipe.add_component(instance=document_embedder, name="document_embedder")
my_pipe.add_component(instance=document_writer, name="document_writer")

# 设定管道组件连接。
my_pipe.connect("file_type_router.text/plain", "text_file_converter.sources")
my_pipe.connect("file_type_router.application/pdf", "pypdf_converter.sources")
my_pipe.connect("file_type_router.application/vnd.openxmlformats-officedocument.wordprocessingml.document", "docx_converter.sources")
my_pipe.connect("text_file_converter", "document_joiner")
my_pipe.connect("pypdf_converter", "document_joiner")
my_pipe.connect("docx_converter", "document_joiner")
my_pipe.connect("document_joiner", "document_cleaner")
my_pipe.connect("document_cleaner", "document_splitter")
my_pipe.connect("document_splitter", "document_embedder")
my_pipe.connect("document_embedder", "document_writer")

from pathlib import Path

# 执行
result=my_pipe.run({"file_type_router": {"sources": list(Path(input_dir).glob("**/*"))}},include_outputs_from={"document_splitter"})
# print(result)
# Out:
# Could not read C:\Users\Administrator\Desktop\操作-大模型测试文件\~$果物】软件介绍（二级二等）.docx and convert it to a DOCX Document, skipping. Error: File is not a zip file
# Batches:   0%|          | 0/8 [00:00<?, ?it/s]
# Document 89397ed7359f5ccbb1c06cf5b6cc84bc1f1883255ba606f3af04afc2a28b43f0 contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document 4080c55e424d939bc09e3faa1c297effaef8f48e9e6926f265bfb802068e95dc contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document a1dc2da9f0c75006a826a592fb2ad8e9f3f91bc9f7b02248cb3eea04b77ce46a contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document a23c986b9dd6bd0c3a88b19ccd6d91018f9c2f971c74bbb1283f0ab5cd625432 contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document 5b895751524d42477b2add007ab0a3f09a59eeca0416a641e9de53254bef5d8c contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0a1b76af9b8ed4c6c8f35c359e9693505502bde5fc108b31e6bdfaf02e2d7811 contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document ba5c1f268cd78202f679782dce406f5f4d189feacd80983b0217f13908b10d32 contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document e3371822b046994f487ca82293943ef1b2cf422d888a5b59d643c603b37b85b5 contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document
contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document c8c6c5562d6dd1bbe18e44c60adbdf1a29a4191bb5d6c1708acfe1cc16444b1f contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document 43fa9fca715c47e5001edc88d354bf70b427e65d6840e4a704eb39b60a780f08 contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document 8662ec7f39bd211baba1680ead014371d7b595ead450ff3a73f307ae5e269f8a contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document 0b39162503a0654e0bfcc0654f6dd4cb48c3ed8c060f48f00b301585f528165f contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document e9b07cef9fb4aa594123f65b81cc4beacf60fe5f7b31daddc5414858ee4303b1 contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document 2aee82fbad4be268f2e0502597dfdf5c771b6d4a34e704907af1a9b85cf2df0a contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.
# Document b5383b07a3eec2be24ccf2eba5a830963992dce3408f107ed5405f907112a8ec contains `meta` values of unsupported types for the keys: docx, _split_overlap. These items will be discarded. Supported types are: str, int, float, bool.

# %%
import os
from haystack.dataclasses import ChatMessage
from haystack_integrations.components.generators.openrouter import OpenRouterChatGenerator

from haystack.components.embedders import SentenceTransformersTextEmbedder
from haystack_integrations.components.retrievers.chroma import ChromaEmbeddingRetriever
from haystack.components.builders import PromptBuilder,ChatPromptBuilder



os.environ["OPENROUTER_API_KEY"] = "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"
def show(chunk):                              # simple streaming callback
    print(chunk.content, end="", flush=True)


template = """
根据给出的文本来回答问题.

文本:
{% for document in documents %}
    {{ document.content }}
{% endfor %}

问题: {{ question }}
你的回答:
"""
RAG_pipe = Pipeline()
RAG_pipe.add_component("embedder", SentenceTransformersTextEmbedder(model="BAAI/bge-small-zh-v1.5"))
RAG_pipe.add_component("retriever", ChromaEmbeddingRetriever(document_store=document_store))

RAG_pipe.connect("embedder.embedding", "retriever.query_embedding")



question = (
    "我们软件的优势是什么？"
)

# 将问题输入进embedder组件的“text”参数，以及prompt的“question”参数，llm组件的大模型配置参数字典，修改生成的最大长度为350
result=RAG_pipe.run(
    {
        "embedder": {"text": question},
        "retriever":{"top_k":3}

    }
)

pprint(result["retriever"]["documents"])
# for i in result["retriever"]["documents"]:
#     print(i.content)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# [Document(id=4bd467401da7e9c127864eead662cad67264c2aed0cded703c051b5082112d9b, content: '这样的定位。这是我们的核心优势。软件优势：软件属于原创创新，以人的行为过程为软件的主体，通过信息过程、统计过程和绩效过程，实现了工作人员行为的标准化过程。服务优势：有', meta: {'split_id': 6, 'page_number': 1, 'split_idx_start': 645, 'file_path': '【成果物】软件介绍（二级二等）.docx', 'source_id': '9a335b3e82c47ebeeb82aa9ff3a2d4e5165defacf98cf8280aeb7af896f50f04'}, score: 0.45290058851242065, embedding: vector of size 512),
#  Document(id=b976cc884673bf171b6b89fc02de0f6f42eecf04d89c33ca4e470a26eef1a481, content: '：定位优势：提供用户最理想的结果，对最终的结果负责。我们是唯一的这样定位的技术服务团队。尤其是对象是企业管理这样的及其复杂的问题，给这样的定位。这是我们的核心优势。软件优势：软件属于原创创新，以人的行...', meta: {'page_number': 1, 'file_path': '【成果物】软件介绍（二级二等）.docx', 'split_id': 2, 'source_id': '9a335b3e82c47ebeeb82aa9ff3a2d4e5165defacf98cf8280aeb7af896f50f04', 'split_idx_start': 539}, score: 0.5787925720214844, embedding: vector of size 512),
#  Document(id=704497d7c68cd81759daad131441a1ad63519303ea590a53f781b7b3600de916, content: '：定位优势：提供用户最理想的结果，对最终的结果负责。我们是唯一的这样定位的技术服务团队。尤其是对象是企业管理这样的及其复杂的问题，给这样的定位。这是我们的核心优势。', meta: {'source_id': '9a335b3e82c47ebeeb82aa9ff3a2d4e5165defacf98cf8280aeb7af896f50f04', 'page_number': 1, 'file_path': '【成果物】软件介绍（二级二等）.docx', 'split_idx_start': 539, 'split_id': 5}, score: 0.6314452886581421, embedding: vector of size 512)]

# %%
import os
from haystack.dataclasses import ChatMessage
from haystack_integrations.components.generators.openrouter import OpenRouterChatGenerator

from haystack.components.embedders import SentenceTransformersTextEmbedder
from haystack_integrations.components.retrievers.chroma import ChromaEmbeddingRetriever
from haystack.components.builders import PromptBuilder
import os
from haystack.dataclasses import ChatMessage
from haystack_integrations.components.generators.openrouter import OpenRouterChatGenerator


os.environ["OPENROUTER_API_KEY"] = "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"

def show(chunk):                              # simple streaming callback
    print(chunk.content, end="", flush=True)

client = OpenRouterChatGenerator(
    model="microsoft/mai-ds-r1:free",                  # let OpenRouter pick a model
    # streaming_callback=show,
    generation_kwargs={
        "provider": {"sort": "throughput"},   # pick the fastest provider
    }
)


template = [ChatMessage.from_user("""
根据给出的文本来回答问题.

文本:
{% for document in documents %}
    {{ document.content }}
{% endfor %}

问题: {{ question }}
你的回答:
""")]

prompt_builder=ChatPromptBuilder(template=template)
llm= OpenRouterChatGenerator(
    model="microsoft/mai-ds-r1:free",                  # let OpenRouter pick a model
    # streaming_callback=show,
    generation_kwargs={
        "provider": {"sort": "throughput"},   # pick the fastest provider
    }
)




#   创建管道节点
RAG_pipe = Pipeline()
RAG_pipe.add_component("text_embedder", SentenceTransformersTextEmbedder(model="BAAI/bge-small-zh-v1.5"))
RAG_pipe.add_component("retriever", ChromaEmbeddingRetriever(document_store=document_store))
RAG_pipe.add_component("prompt_builder", prompt_builder)
RAG_pipe.add_component("llm", llm)


# 连接管道节点
RAG_pipe.connect("text_embedder.embedding", "retriever.query_embedding")
RAG_pipe.connect("retriever", "prompt_builder")
RAG_pipe.connect("prompt_builder.prompt", "llm.messages")


question = "我们软件的最大优势是什么"

response = RAG_pipe.run({"text_embedder": {"text": question}, "prompt_builder": {"question": question}})

print(response["llm"]["replies"][0].text)
# Out:
# ChatPromptBuilder has 2 prompt variables, but `required_variables` is not set. By default, all prompt variables are treated as optional, which may lead to unintended behavior in multi-branch pipelines. To avoid unexpected execution, ensure that variables intended to be required are explicitly set in `required_variables`.
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 根据文本内容，我们软件的最大优势是**标准优势**，具体体现在：
#
# 1. **颠覆性创新标准**：提出了企业运行和生存的新方向，系统性地构建了完整的企业管理新标准，从根本上颠覆传统管理思路。"这个标准，颠覆了过去人们对企业管理的思路和方法，会给企业带来巨大的效益"。
#
# 2. **结果导向**：通过管理过程自动化、人员行为自主化与标准化，**直接实现企业管理结果升级**。在软硬件技术支撑下，"基础管理模块实现的管理结果是...企业带来巨大的效益"。
#
# 3. **唯一性定位**：强调"我们是唯一这样定位的技术服务团队"，将标准优势与核心定位绑定，突出其在复杂的企业管理领域的独特性。
#
# 其他如**技术整合优势（云服务+物联网全栈服务）**和**"软件即用性"（不用实施、立即会用）**是对标准优势的支撑，而标准优势本身成为定义行业新规则的差异化竞争力。
